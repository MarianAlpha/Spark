# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# En el primer grafico Spark relaiza las transformaciones 1,2 y 3 dos veces por la bifurcacion, es po ello que es mejor poner un persist() despues de la transformacion 3 para guardar el resultado y asi solo ejecutar estas tranformaciones una sola vez. Tambien se usa en procesamientos muy pesados para realizar un particionamiento.
